# %%
import config
import requests
from bs4 import BeautifulSoup 
from PIL import Image, ImageFont, ImageDraw
import datetime
import re
from bs4.builder._htmlparser import HTMLParserTreeBuilder

# %%
website = 'https://www.google.com/search?q=weather+london'

# %%
r = requests.request('GET', website)

# %%
soup = BeautifulSoup(requests.get(website).content,'html.parser')

# %%
allDivs = soup.find_all("div")
allDivs
# Out:
# [<div class="cOl4Id" dir="ltr"><a href="/?sa=X&amp;ved=0ahUKEwijycr21oT0AhUCr1YBHQklBr8QOwgC"><span class="V6gwVd">G</span><span class="iWkuvd">o</span><span class="cDrQ7">o</span><span class="V6gwVd">g</span><span class="ntlR9">l</span><span class="iWkuvd tJ3Myc">e</span></a></div>,
# ...

# %%
soup.find_all("div", class_="wob_df")
# Out:
# []

# %%
soup.find_all("div", class_=re.compile(r"^wob_df"))
# Out:
# []

# %%
soup.find("div", attrs={"id": "wob_dp"})

# %%
soup.select("div#wob_dp")
# Out:
# []

# %%
# Out:
# None
